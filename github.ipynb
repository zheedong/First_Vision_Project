# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd "/content/drive/My Drive/Colab Notebooks/Computer_Vision"

# %%
# !git config --global user.email "zheedong@gmail.com"
# !git config --global user.name "zheedong"

# %%
# !git init

# %%
# !git add .

# %%
# !git rm --cached . -rf

# %%
# !git commit -m "Fully_Connted_Layer, Let's get stared!"     # commit message 수정

# %%
#리모트 시 주소에 사용자 이름과 패스워드를 모두 적어야합니다.
# !git remote rm origin

# !git remote add origin https://zheedong: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@github.com/zheedong/Stanford_CS231n_assignment_2021.git
# 이때 만약 “fatal: remote origin already exists” 라는 에러메시지가 뜨면 
# 기존 remote를 제거하고 다시 설정합니다.

# %%
# PULL
# !git pull origin master

# %%
# PUSH
# !git push -u origin master
